# %% [markdown]
# # Exercices Remise en forme - TD 1 (v 2025-3b)
# ![](https://deptinfo-ensip.univ-poitiers.fr/blank/Exercices_2A_TD1-sujet.ipynb:egarre06)

# %%
# Chargement de la feuille de style
from IPython.display import HTML, IFrame
HTML(url="https://ensip.gitlab.io/notebooks/data/nb2.css")

# %% [markdown]
# Traditionnellement, on commence par des trucs super faciles...
# Voyons si cette année, vous pouvez être un peu plus challengés 😀

# %% [markdown]
# ## Advent of Code 2024 - Day 2: Red-Nosed Reports
#
# L’Historien en chef est toujours présent pour le grand lancement du traîneau de Noël. Mais
# impossible de le retrouver. Les Historiens et vous, êtes à sa recherche.
#
# ### Première partie
#
# <!-- Fortunately, the first location The Historians want to search isn't a
# long walk from the Chief Historian's office.
#
# While the Red-Nosed Reindeer nuclear fusion/fission
# plant appears to contain no sign
# of the Chief Historian, the engineers there run up to you as soon as
# they see you. Apparently, they *still* talk about the time Rudolph was
# saved through molecular synthesis from a single electron.
#
# They're quick to add that - since you're already here - they'd really
# appreciate your help analyzing some unusual data from the Red-Nosed
# reactor. You turn to check if The Historians are waiting for you, but
# they seem to have already divided into groups that are currently
# searching every corner of the facility. You offer to help with the
# unusual data.
#
# The unusual data (your puzzle input) consists of many *reports*, one
# report per line. Each report is a list of numbers called *levels* that
# are separated by spaces. For example: -->
#
# Heureusement, le premier endroit que les Historiens souhaitent fouiller ne se trouve pas à une longue distance à pied du bureau de l’Historien en chef.
#
# Bien que la centrale de fusion/fission nucléaire du Renne au Nez Rouge ne semble contenir aucune trace de l’Historien en chef, les ingénieurs sur place accourent vers vous dès qu’ils vous aperçoivent. Apparemment, ils parlent encore de l’époque où Rudolph a été sauvé grâce à une synthèse moléculaire à partir d’un seul électron.
#
# Ils ajoutent rapidement que — puisque vous êtes déjà ici — ils apprécieraient grandement votre aide pour analyser des données inhabituelles provenant du réacteur au Nez Rouge. Vous vous retournez pour vérifier si les Historiens vous attendent, mais ils semblent s’être déjà divisés en groupes qui fouillent actuellement chaque recoin de l’installation. Vous proposez d’aider à analyser ces données inhabituelles.
#
# Les données inhabituelles (les données d’entrée de votre énigme) consistent en de nombreux rapports, à raison d’un rapport par ligne. Chaque rapport est une liste de nombres appelés niveaux, séparés par des espaces. Par exemple :
#
# ```
# 7 6 4 2 1
# 1 2 7 8 9
# 9 7 6 2 1
# 1 3 2 4 5
# 8 6 4 4 1
# 1 3 6 7 9
# ```
#
# <!--
# This example data contains six reports each containing five levels.
#
# The engineers are trying to figure out which reports are *safe*. The
# Red-Nosed reactor safety systems can only tolerate levels that are
# either gradually increasing or gradually decreasing. So, a report only
# counts as safe if both of the following are true:
#
# - The levels are either *all increasing* or *all decreasing*.
# - Any two adjacent levels differ by *at least one* and *at most
#   three*.
#
# In the example above, the reports can be found safe or unsafe by
# checking those rules:
# -->
#
# Ces données d’exemple contiennent six rapports, chacun comportant cinq niveaux.
#
# Les ingénieurs essaient de déterminer quels rapports sont sûrs. Les systèmes de sécurité du réacteur au Nez Rouge ne peuvent tolérer que des niveaux qui augmentent progressivement ou qui diminuent progressivement. Ainsi, un rapport n’est considéré comme sûr que si les deux conditions suivantes sont réunies :
#
# Les niveaux sont soit tous croissants, soit tous décroissants.
#
# Deux niveaux adjacents diffèrent de au moins un et au plus trois.
#
# Dans l’exemple ci-dessus, on peut déterminer si les rapports sont sûrs ou non en vérifiant ces règles :
#
#
# - `7 6 4 2 1`: *Sûr* car les niveaux diminuent tous de 1 ou 2.
# - `1 2 7 8 9`: *Non sûr* car `2 7` correspond à une augmentation de 5.
# - `9 7 6 2 1`: *Non sûr* car `6 2` correpond à une diminution de 4.
# - `1 3 2 4 5`: *Non sûr*  car `1 3` correspond à une augmentation mais `3 2` à
#   une diminution.
# - `8 6 4 4 1`: *Non sûr* car `4 4` n'est ni une augmentation, nin une diminution.
# - `1 3 6 7 9`: *Sûr* car les niveaux augmentent à chaque fois de 1, 2 ou 3.
#
# <!--
# So, in this example, *`2`* reports are *safe*.
#
# Analyze the unusual data from the engineers. *How many reports are
# safe?*
# -->
#
# Donc, dans l'exemple précédent, *`2`* rapoorts sont *sûrs*.
#
# Analysez les données inhabituelles fournies par les ingénieurs. *Combien de rapports sont sûrs ?*

# %% [markdown]
# **Vous pouvez >>[télécharger le fichier de données](https://ensip.gitlab.io/notebooks/data/aoc/aoc_2024_2a.txt)<<**.
# Enregistrez-le  **au même endroit que votre notebook sans le renommer** (si vous ne voyez pas pourquoi il faut faire ça
# demandez et je vous le dirai), puis regardez-ci dessous comment le lire.

# %%
# Le listing des rapports (vos données d'entrée) sont dans un fichier.
# Voici un moyen (moderne) de le lire. Retenez comment on fait...
#
from pathlib import Path
report = Path("aoc_2024_2a.txt").read_text()
print(report[:200], "...")

# %% [markdown]
# Lorsque vous avez la réponse... [>>>rendez-vous sur le
# *podium*<<<](https://ladigitale.dev/digilock/#/l/679f2a5a44d70) !

# %%
# Votre code ici

# %% [markdown]
# ### Seconde partie
#
# <!--
# The engineers are surprised by the low number of safe reports until
# they realize they forgot to tell you about the Problem Dampener.
#
# The Problem Dampener is a reactor-mounted module that lets the
# reactor safety systems tolerate a single bad level in what would
# otherwise be a safe report. It's like the bad level never happened!
#
# Now, the same rules apply as before, except if removing a single
# level from an unsafe report would make it safe, the report instead
# counts as safe.
#
# More of the above example's reports are now safe:
# -->
#
# Les ingénieurs sont surpris par le faible nombre de rapports sûrs, jusqu’à ce qu’ils réalisent qu’ils ont oublié de vous parler de **l’Amortisseur de Problèmes**.
#
# L’Amortisseur de Problèmes est un module monté sur le réacteur qui permet aux systèmes de sécurité du réacteur de tolérer un seul niveau incorrect dans un rapport qui serait autrement sûr. C’est comme si le niveau problématique n’avait jamais existé !
#
# Désormais, les mêmes règles s’appliquent qu’auparavant, sauf que si le fait de retirer un seul niveau d’un rapport non sûr le rend sûr, alors le rapport est considéré comme sûr.
#
# Davantage de rapports de l’exemple ci-dessus sont maintenant sûrs :
#
# - `7 6 4 2 1` : Sûr sans retirer aucun niveau.
# - `1 2 7 8 9` : Non sûr quel quel soit le niveau retiré.
# - `9 7 6 2 1` : Non sûr quel quel soit le niveau retiré.
# - `1 3 2 4 5` : Sûr grâce au retrait du second niveau : `3`.
# - `8 6 4 4 1` : Sûr grâce au retrait du troisième niveau : `4`.
# - `1 3 6 7 9` : Sûr sans retirer aucun niveau.
#
#
# <!--
# Thanks to the Problem Dampener, 4 reports are actually safe!
#
# Update your analysis by handling situations where the Problem
# Dampener can remove a single level from unsafe reports. How many
# reports are now safe?
# -->
#
# Grâce à l’Amortisseur de Problèmes, 4 rapports sont en réalité sûrs !
#
# Mettez à jour votre analyse en tenant compte des situations où l’Amortisseur de Problèmes peut
# retirer un seul niveau des rapports non sûrs. Combien de rapports sont maintenant sûrs ?
#
# Lorsque vous avez la réponse de la seconde partie...
# [>>>rendez-vous sur le
# *podium*<<<](https://ladigitale.dev/digilock/#/l/69763d34b5e3b) !

# %% [markdown]
# ### Améliorations ?
#
# Vous avez été rapide ? Quoi qu'il en soit, votre code n'est peut être pas de très bonne
# qualité. Vous pouvez :
# - le faire relire à l'enseignant, il vous dira ce qui est améliorable
# - regarder le document : *Bonne pratiques et joli code*, il recense quelqus règles à respecter
# - le soumettre à un LLM avec par exemple ce prompt :
# > Le code suivant est fonctionnel.
# > Explique moi comment à quoi il sert et comment il fonctionne, et donne moi des pistes
# > d'amélioration pour avoir un code plus lisible et conforme aux standards d'écriture Python.
# > Voici le code :
# > ...

# %% [markdown]
# ## Autres exercices...
#
# <div class='alert alert-warning'>
#
# Vous devez disposer d'un token de connection pour utiliser le système de correction automatique.
# Si votre token de connexion n'est pas prérempli, vous pouvez le récupérer
# [>>ici<<](https://deptinfo-ensip.univ-poitiers.fr/pyapps2/pyjudge/gettoken).
#
# </div>

# %%
import urllib
exec(urllib.request.urlopen("https://ensip.gitlab.io/pyjudge/pyjudge_client.py").read())
pj = PyJudge("https://deptinfo-ensip.univ-poitiers.fr/pyjudge")
pj.auth("0:/ensip/egarre06:310726.l_QtJJ_eTaOWu4s9x35WKx9Wgko");

# %% [markdown]
# ## Années bissextiles (Bissextile)
# [Énoncé](https://info86.frama.io/banque_exercices/bissextile/)

# %%
# Votre code ici :
def bissextile(n):
    pass

# %%
# Vos tests (assertions) ici :

# %%
# Test automatique (à décommenter)
# pj.feedback(bissextile, "0:bissextile", mode="html")

# %% [markdown]
# ## Copies superficielles (CopiesSuperficielles)
#
# Considérez la portion de code suivant et exécutez là

# %%
a=[1, [1, 2]]
print(id(a), id(a[0]), id(a[1]) )

b=list(a)
print(id(b), id(b[0]), id(b[1]) )

print(a, b)

# %% [markdown]
# On modifie la liste `b` et on regarde si la modification a lieu dans `a` aussi :

# %%
b[0] = 42
print(a, b)

# %% [markdown]
# Non. La modification ne se voit que dans `b`.
#
# Autre modification dans `b` :

# %%
b[1][0] = 54
print(a, b)

# %% [markdown]
# Cette fois-ci, la modification a lieu à la fois dans `a` et dans `b`. Expliquez.

# %% [markdown]
# ## Numéro de carte de crédit (NumeroCarteBancaire)
# [Énoncé](https://ensip.gitlab.io/banque_exos_01/numero_carte_bancaire)

# %%
# Votre code ici
def carte_valide(num):
    return False

# %%
# Vos tests (assertions) ici :

# %%
# Test automatique (à décommenter)
# pj.feedback(carte_valide, "bkls01:numero_carte_bancaire", mode="html")

# %% [markdown]
# ## Suite du lézard (SuiteLezard)
# [Énoncé](https://ensip.gitlab.io/banque_exos_01/suite_lezard)

# %%
# Votre code ici :
def suitelezard(n):
    ...

# %%
# Vos tests (assertions) ici :

# %%
# Test automatique (à décommenter)
# pj.feedback(suitelezard, "bkls01:suite_lezard", mode="html")

# %% [markdown]
# ## Suite du Prouhet-Thue-Morse (SuitePTM)
# [Énoncé](https://ensip.gitlab.io/banque_exos_01/suite_ptm)

# %%
# Votre code ici :
def suite_ptm(n):
    ...

# %%
# Vos tests (assertions) ici :

# %%
# Test automatique (à décommenter)
# pj.feedback(suite_ptm, "bkls01:suite_ptm", mode="html")

# %% [markdown]
# ## L'escalier diabolique (CompteEscalier)
# [Énoncé](https://ensip.gitlab.io/banque_exos_01/escalier_diabolique)

# %%
# Votre code ici : 
def compte_escalier(n):
    return 0

# %%
# Vos tests (assertions) ici :

# %%
# Test automatique (à décommenter)
# pj.feedback(compte_escalier, "bkls01:escalier_diabolique", mode="html")

# %% [markdown]
# ## Planche de Galton (PlancheGalton)
#
# La [planche de Galton](https://fr.wikipedia.org/wiki/Planche_de_Galton) est un dispositif physique qui illustre, par exemple, la convergence d'une loi binomiale vers une loi normale.
#
# L'objectif de l'exercice est de réaliser un programme qui simule une planche de Galton (numériquement).

# %% [markdown]
# **Exécutez la cellule suivante pour voir une vidéo de la planche de Galton**

# %%
# %%html
#
# <iframe width="500" height="300" src="https://upload.wikimedia.org/wikipedia/commons/d/dc/Galton_box.webm" frameborder="0" allowfullscreen>
# </iframe>

# %% [markdown]
# L'objectif est de simuler la chute de billes et d'observer leur répartiton en bas de la planche.
# Pour atteindre cet objectif, il est conseillé d'écrire une fonction `bille`, qui prend en paramètre
# le nombre de rangées de plots à traverser et renvoie l'abscisse de la bille à la fin de la chute.
# Il est pratique de supposer que la bille est lâchée à l'abscisse 0. Une bille déviée 2 fois
# vers la droite se retrouvera à l'abscisse 2.
#
# Dans un second temps, on écrira une fonction `simulation` qui prend en paramètres le nombre de
# billes à utiliser, et le nombre de rangées de plots, et construira une liste contenant la répartition
# des billes.
#
# Par exemple, pour 10000 billes, et 8 étages de plots, on pourrait obtenir cette
# répartition `39, 318, 1090, 2228, 2728, 2141, 1097, 318, 41`
#
# Si vous avez besoin d'importer un module (`random`... au hasard...), faites le correctement :
# [Guide de l'autostoppeur Python / section modules](https://python-guide-pt-br.readthedocs.io/fr/latest/writing/structure.html#modules)

# %%
# Votre code ici

# %% [markdown]
# Réaliser un diagramme à barres verticales représentant les résultats pour 13 colonnes, et 1000 billes.
# Chaque barre du diagramme correspondra au nombre de billes dans la colonne. Il y aura donc 13 barres.

# %% [markdown]
# ### Question subsidiaire
#
# Vérifiez que la répartition des billes suit effectivement une loi normale :
# $$f(x) = \frac{1}{\sigma\sqrt{2\pi}}\exp^{-\frac{1}{2}\left(\frac{x-\mu}{\sigma}\right)^2}$$
#
# Pour ça, vous devrez estimer la moyenne $\mu$ et l'écart type $\sigma$. Vous pouvez le faire avec le module
# de statistiques de la bibliothèque standard Python :
#
# ~~~python
# import statistics
# vals = [0, 1, 2, 3, 2]
# print(statistics.mean(vals))
# print(statistics.stdev(vals))
# ~~~
# ~~~python
# 1.6
# 1.140175425099138
# ~~~
#
# Mais attention, il vous faudra construire la liste des réalisations (variable `vals` ci-dessus) que vous n'avez pas de
# manière explicite.
#
# Vous pouvez aussi utiliser les formules standard (racine de la moyenne des (écarts à la moyenne au carré)...).

# %%
# Vos calculs et le (beau) graphique ici.
